# %%
# !pip show streamlit
# !pip show numpy
# !pip show Pillow
# !pip show tensorflow
# !pip show scipy
# !pip show opencv-python-headless
# !pip show streamlit-webrtc
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Yogkan\OneDrive - Temasek Polytechnic\New folder\envs\MLDP_APR23_P01\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "C:\Users\Yogkan\OneDrive - Temasek Polytechnic\New folder\envs\MLDP_APR23_P01\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Yogkan\OneDrive - Temasek Polytechnic\New folder\envs\MLDP_APR23_P01\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "C:\Users\Yogkan\OneDrive - Temasek Polytechnic\New folder\envs\MLDP_APR23_P01\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
# ...
